-- %%
DROP TABLE employees;
CREATE TABLE employees ( employee_id int , employee_name varchar(100) , joined_date DATE);

-- %%
INSERT INTO employees values( 1, 'XYZ' , to_date('01-JAN-2018', 'dd-MMM-yyyy'));
INSERT INTO employees VALUES( 3, 'XYZ' , to_date('02-JAN-2020', 'dd-MMM-yyyy'));
